# %% [markdown]
# # Week05 - Hands on with Pandas

# %%
import pandas as pd

# %% [markdown]
# ## Loading the data
# This structure remains the same. If you have another google spreadsheet, you only have to change the sheet_id

# %%
base_url = "https://docs.google.com/spreadsheets/d/"
url_id = "1NV-k5237esNE6lugwYw4hZVoRcYi8SFtG4fzX3aokAo/"
export = "export/format=excel"

whole_url = base_url + url_id + export

# %% [markdown]
# Different python and pandas versions exist and they handle dataframes differently regarding specific cases. For example, this dataset contains many values as "None". In my setup, all "None" values are instantly converted as NaN (missing valueas). So it appears the same as in my setup, you need to specify <code>na_values="None"</code>

# %%
df = pd.read_excel(whole_url, na_values="None")

# %% [markdown]
# ### Description of the dataset
#
# This is a dataset of classified for apartments for rent in USA.
# source: https://archive.ics.uci.edu/dataset/555/apartment+for+rent+classified
#
# - **id** — unique identifier of the apartment
# - **category** — category of the classified
# - **title** — title text of the apartment
# - **body** — body text of the apartment
# - **amenities** — features like AC, basketball court, cable, gym, internet access, pool, refrigerator, etc.
# - **bathrooms** — number of bathrooms
# - **bedrooms** — number of bedrooms
# - **currency** — currency of the price
# - **fee** — fee associated with the apartment
# - **has_photo** — whether the apartment has a photo
# - **pets_allowed** — allowed pets (dogs, cats, etc.)
# - **price** — rental price of the apartment
# - **price_display** — formatted price shown to the reader
# - **price_type** — price expressed in USD
# - **square_feet** — size of the apartment
# - **address** — address of the apartment
# - **cityname** — city where the apartment is located
# - **state** — state where the apartment is located
# - **latitude** — geographic latitude of the apartment
# - **longitude** — geographic longitude of the apartment
# - **source** — origin of the classified
# - **time** — timestamp when the classified was created

# %% [markdown]
# ## Inspecting the dataset
# All analysis begin by asking questions.

# %% [markdown]
# ### What is the structure of my dataframe?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             10000 non-null  int64
#  1   category       10000 non-null  object
#  2   title          10000 non-null  object
#  3   body           10000 non-null  object
#  4   amenities      6451 non-null   object
#  5   bathrooms      9966 non-null   float64
#  6   bedrooms       9993 non-null   float64
#  7   currency       10000 non-null  object
#  8   fee            10000 non-null  object
#  9   has_photo      10000 non-null  object
#  10  pets_allowed   5837 non-null   object
#  11  price          10000 non-null  int64
#  12  price_display  10000 non-null  object
#  13  price_type     10000 non-null  object
#  14  square_feet    10000 non-null  int64
#  15  address        6673 non-null   object
#  16  cityname       9923 non-null   object
#  17  state          9923 non-null   object
#  18  latitude       9990 non-null   float64
#  19  longitude      9990 non-null   float64
#  20  source         10000 non-null  object
#  21  time           10000 non-null  int64
# dtypes: float64(4), int64(4), object(14)
# memory usage: 1.7+ MB

# %% [markdown]
# ### How can I visualize the first ten columns?
# Make sure to set <code>pd.set_option('display.max_columns', None)</code>

# %%
pd.set_option('display.max_columns', None)
df.head(5)
# Out:
#            id                category  \
# 0  5668626895  housing/rent/apartment
# 1  5664597177  housing/rent/apartment
# 2  5668626833  housing/rent/apartment
# 3  5659918074  housing/rent/apartment
# 4  5668626759  housing/rent/apartment
#
#                                                title  \
# 0  Studio apartment 2nd St NE, Uhland Terrace NE,...
# 1                  Studio apartment 814 Schutte Road
# 2  Studio apartment N Scott St, 14th St N, Arling...
# 3                     Studio apartment 1717 12th Ave
# 4  Studio apartment Washington Blvd, N Cleveland ...
#
#                                                 body amenities  bathrooms  \
# 0  This unit is located at second St NE, Uhland T...       NaN        NaN
# 1  This unit is located at 814 Schutte Road, Evan...       NaN        NaN
# 2  This unit is located at N Scott St, 14th St N,...       NaN        1.0
# 3  This unit is located at 1717 12th Ave, Seattle...       NaN        1.0
# 4  This unit is located at Washington Blvd, N Cle...       NaN        NaN
#
#    bedrooms currency fee  has_photo pets_allowed  price price_display  \
# 0       0.0      USD  No  Thumbnail          NaN    790           790
# 1       1.0      USD  No  Thumbnail          NaN    425           425
# 2       0.0      USD  No  Thumbnail          NaN   1390          1390
# 3       0.0      USD  No  Thumbnail          NaN    925           925
# 4       0.0      USD  No  Thumbnail          NaN    880           880
#
#   price_type  square_feet           address    cityname state  latitude  \
# 0    Monthly          101               NaN  Washington    DC   38.9057
# 1    Monthly          106    814 Schutte Rd  Evansville    IN   37.9680
# 2    Monthly          107               NaN   Arlington    VA   38.8910
# 3    Monthly          116  1717 12th Avenue     Seattle    WA   47.6160
# 4    Monthly          125               NaN   Arlington    VA   38.8738
#
#    longitude     source        time
# 0   -76.9861  RentLingo  1577359415
# 1   -87.6621  RentLingo  1577017063
# 2   -77.0816  RentLingo  1577359410
# 3  -122.3275  RentLingo  1576667743
# 4   -77.1055  RentLingo  1577359401

# %% [markdown]
# ### How can I get the names of all columns?

# %%
df.columns
# Out:
# Index(['id', 'category', 'title', 'body', 'amenities', 'bathrooms', 'bedrooms',
#        'currency', 'fee', 'has_photo', 'pets_allowed', 'price',
#        'price_display', 'price_type', 'square_feet', 'address', 'cityname',
#        'state', 'latitude', 'longitude', 'source', 'time'],
#       dtype='object')

# %% [markdown]
# ### How do I know quickly the number of rows and columns of my df?

# %%
df.shape
# Out:
# (10000, 22)

# %% [markdown]
# ## Index and Slicing

# %% [markdown]
# ### How do I select a column?

# %%
df["pets_allowed"]
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 9995    NaN
# 9996    NaN
# 9997    NaN
# 9998    NaN
# 9999    NaN
# Name: pets_allowed, Length: 10000, dtype: object

# %%
#use double square brackets to be shown with df format
df[["pets_allowed"]]
# Out:
#      pets_allowed
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 9995          NaN
# 9996          NaN
# 9997          NaN
# 9998          NaN
# 9999          NaN
#
# [10000 rows x 1 columns]

# %% [markdown]
# ### How do I know the unique values in one column?

# %%
df["pets_allowed"].unique()
# Out:
# array([nan, 'Cats,Dogs', 'Cats', 'Dogs'], dtype=object)

# %% [markdown]
# ### How do I know how many unique values there are in one column?

# %%
df["pets_allowed"].nunique(dropna=True)
# Out:
# 3

# %% [markdown]
# ### I want to know the specific counts of the unique values.

# %%
df["pets_allowed"].value_counts(dropna=False)
# Out:
# pets_allowed
# Cats,Dogs    5228
# NaN          4163
# Cats          485
# Dogs          124
# Name: count, dtype: int64

# %% [markdown]
# ### How do I select only the second row by index position?

# %%
df.iloc[2]
# Out:
# id                                                      5668626833
# category                                    housing/rent/apartment
# title            Studio apartment N Scott St, 14th St N, Arling...
# body             This unit is located at N Scott St, 14th St N,...
# amenities                                                      NaN
# bathrooms                                                      1.0
# bedrooms                                                       0.0
# currency                                                       USD
# fee                                                             No
# has_photo                                                Thumbnail
# pets_allowed                                                   NaN
# price                                                         1390
# price_display                                                 1390
# price_type                                                 Monthly
# square_feet                                                    107
# address                                                        NaN
# cityname                                                 Arlington
# state                                                           VA
# latitude                                                    38.891
# longitude                                                 -77.0816
# source                                                   RentLingo
# time                                                    1577359410
# Name: 2, dtype: object

# %%
# or use double square brackets
df.iloc[[2]]
# Out:
#            id                category  \
# 2  5668626833  housing/rent/apartment
#
#                                                title  \
# 2  Studio apartment N Scott St, 14th St N, Arling...
#
#                                                 body amenities  bathrooms  \
# 2  This unit is located at N Scott St, 14th St N,...       NaN        1.0
#
#    bedrooms currency fee  has_photo pets_allowed  price price_display  \
# 2       0.0      USD  No  Thumbnail          NaN   1390          1390
#
#   price_type  square_feet address   cityname state  latitude  longitude  \
# 2    Monthly          107     NaN  Arlington    VA    38.891   -77.0816
#
#       source        time
# 2  RentLingo  1577359410

# %% [markdown]
# ### How do I select the first 8 rows with all columns?

# %%
df.iloc[:8,:]
# Out:
#            id                category  \
# 0  5668626895  housing/rent/apartment
# 1  5664597177  housing/rent/apartment
# 2  5668626833  housing/rent/apartment
# 3  5659918074  housing/rent/apartment
# 4  5668626759  housing/rent/apartment
# 5  5667891676  housing/rent/apartment
# 6  5668627426  housing/rent/apartment
# 7  5668626687  housing/rent/apartment
#
#                                                title  \
# 0  Studio apartment 2nd St NE, Uhland Terrace NE,...
# 1                  Studio apartment 814 Schutte Road
# 2  Studio apartment N Scott St, 14th St N, Arling...
# 3                     Studio apartment 1717 12th Ave
# 4  Studio apartment Washington Blvd, N Cleveland ...
# 5                          0 BR in New York NY 10019
# 6                   Studio apartment 2432 Penmar Ave
# 7  Studio apartment Oak St NW, 16th St NW, Washin...
#
#                                                 body  \
# 0  This unit is located at second St NE, Uhland T...
# 1  This unit is located at 814 Schutte Road, Evan...
# 2  This unit is located at N Scott St, 14th St N,...
# 3  This unit is located at 1717 12th Ave, Seattle...
# 4  This unit is located at Washington Blvd, N Cle...
# 5  **RARE GEM WITH PRIVATE OUTDOOR TERRACE****AVA...
# 6  This unit is located at 2432 Penmar Ave, Venic...
# 7  This unit is located at Oak St NW, 16th St NW,...
#
#                                      amenities  bathrooms  bedrooms currency  \
# 0                                          NaN        NaN       0.0      USD
# 1                                          NaN        NaN       1.0      USD
# 2                                          NaN        1.0       0.0      USD
# 3                                          NaN        1.0       0.0      USD
# 4                                          NaN        NaN       0.0      USD
# 5  Dishwasher,Elevator,Patio/Deck,Pool,Storage        1.0       0.0      USD
# 6                                          NaN        NaN       0.0      USD
# 7                                          NaN        NaN       0.0      USD
#
#   fee  has_photo pets_allowed  price price_display price_type  square_feet  \
# 0  No  Thumbnail          NaN    790           790    Monthly          101
# 1  No  Thumbnail          NaN    425           425    Monthly          106
# 2  No  Thumbnail          NaN   1390          1390    Monthly          107
# 3  No  Thumbnail          NaN    925           925    Monthly          116
# 4  No  Thumbnail          NaN    880           880    Monthly          125
# 5  No  Thumbnail          NaN   2475          2475    Monthly          130
# 6  No  Thumbnail          NaN   1800          1800    Monthly          132
# 7  No  Thumbnail          NaN    840           840    Monthly          136
#
#               address    cityname state  latitude  longitude     source  \
# 0                 NaN  Washington    DC   38.9057   -76.9861  RentLingo
# 1      814 Schutte Rd  Evansville    IN   37.9680   -87.6621  RentLingo
# 2                 NaN   Arlington    VA   38.8910   -77.0816  RentLingo
# 3    1717 12th Avenue     Seattle    WA   47.6160  -122.3275  RentLingo
# 4                 NaN   Arlington    VA   38.8738   -77.1055  RentLingo
# 5    350 West 50th St   Manhattan    NY   40.7629   -73.9885   Listanza
# 6  2432 Penmar Avenue      Venice    CA   33.9932  -118.4609  RentLingo
# 7                 NaN  Washington    DC   38.9328   -77.0297  RentLingo
#
#          time
# 0  1577359415
# 1  1577017063
# 2  1577359410
# 3  1576667743
# 4  1577359401
# 5  1577289784
# 6  1577359461
# 7  1577359393

# %% [markdown]
# ### How do I select the first 10 rows with the first five columns?

# %%
df.iloc[:10, :5]
# Out:
#            id                category  \
# 0  5668626895  housing/rent/apartment
# 1  5664597177  housing/rent/apartment
# 2  5668626833  housing/rent/apartment
# 3  5659918074  housing/rent/apartment
# 4  5668626759  housing/rent/apartment
# 5  5667891676  housing/rent/apartment
# 6  5668627426  housing/rent/apartment
# 7  5668626687  housing/rent/apartment
# 8  5668610290  housing/rent/apartment
# 9  5668627023  housing/rent/apartment
#
#                                                title  \
# 0  Studio apartment 2nd St NE, Uhland Terrace NE,...
# 1                  Studio apartment 814 Schutte Road
# 2  Studio apartment N Scott St, 14th St N, Arling...
# 3                     Studio apartment 1717 12th Ave
# 4  Studio apartment Washington Blvd, N Cleveland ...
# 5                          0 BR in New York NY 10019
# 6                   Studio apartment 2432 Penmar Ave
# 7  Studio apartment Oak St NW, 16th St NW, Washin...
# 8                       Studio apartment 333 Hyde St
# 9   Studio apartment A St SE, 19th St SE, Washington
#
#                                                 body  \
# 0  This unit is located at second St NE, Uhland T...
# 1  This unit is located at 814 Schutte Road, Evan...
# 2  This unit is located at N Scott St, 14th St N,...
# 3  This unit is located at 1717 12th Ave, Seattle...
# 4  This unit is located at Washington Blvd, N Cle...
# 5  **RARE GEM WITH PRIVATE OUTDOOR TERRACE****AVA...
# 6  This unit is located at 2432 Penmar Ave, Venic...
# 7  This unit is located at Oak St NW, 16th St NW,...
# 8  This unit is located at 333 Hyde St, San Franc...
# 9  This unit is located at A St SE, 19th St SE, W...
#
#                                      amenities
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# 5  Dishwasher,Elevator,Patio/Deck,Pool,Storage
# 6                                          NaN
# 7                                          NaN
# 8                                 Refrigerator
# 9                                          NaN

# %% [markdown]
# ### Can I select rows by position and columns by name

# %%
#selecting rows by label and index
df.loc[5:25, ["cityname", "state"]]
# Out:
#          cityname state
# 5       Manhattan    NY
# 6          Venice    CA
# 7      Washington    DC
# 8   San Francisco    CA
# 9      Washington    DC
# 10     Washington    DC
# 11     Washington    DC
# 12         Tucson    AZ
# 13     Washington    DC
# 14  San Francisco    CA
# 15       New Bern    NC
# 16       New Bern    NC
# 17         Spring    TX
# 18        Vallejo    CA
# 19       Marietta    GA
# 20      Charlotte    NC
# 21    Tallahassee    FL
# 22            NaN   NaN
# 23        Phoenix    AZ
# 24      Riverview    FL
# 25      Lafayette    AL

# %% [markdown]
# ## Conditional selection

# %% [markdown]
# In class we learned that we can select portion of the dataframe based on specific conditions
#
# - Only one condition
# <code>df[df[condition]]</code>
#
# - Two conditions that must be fulfilled
# <code>df[df[condition1 & condition2]]</code>
#
#
# - Either one condition or the other
# <code>df[df[condition1 | condition2]]</code>
#
#
# Using <code>df[df[condition]]</code> is useful for quick views. But usually, it is always recommended to use <code>df.loc[df[condition]]</code>.

# %% [markdown]
# ### I want to get only those aparments who allow only Cats

# %%
df.loc[df["pets_allowed"]=="Cats"]
# Out:
#               id                category  \
# 40    5668625234  housing/rent/apartment
# 45    5668639708  housing/rent/apartment
# 48    5668636830  housing/rent/apartment
# 185   5668616388  housing/rent/apartment
# 189   5664583637  housing/rent/apartment
# ...          ...                     ...
# 9828  5664592650  housing/rent/apartment
# 9837  5664582953  housing/rent/apartment
# 9857  5668627365  housing/rent/apartment
# 9905  5659919613  housing/rent/apartment
# 9914  5664578473  housing/rent/apartment
#
#                                          title  \
# 40      Studio apartment 420 W. Fullerton Pkwy
# 45    Studio apartment 1008 North 109th Street
# 48        Studio apartment 202 E. HOLLY STREET
# 185       Studio apartment 404 Chamberlain Ave
# 189        Studio apartment 621 Begonia Avenue
# ...                                        ...
# 9828                Two BR 703 N 13th St. #308
# 9837                 Two BR 2215 Monument Ave.
# 9857                        Four BR 22 Gray St
# 9905         Five BR 14815 SE River Forest Dr.
# 9914                 Seven BR 423 N Carroll St
#
#                                                    body  \
# 40    This unit is located at 420 W. Fullerton Pkwy,...
# 45    This unit is located at 1008 North 109th Stree...
# 48    This unit is located at 202 E. HOLLY STREET, B...
# 185   This unit is located at 404 Chamberlain Ave, M...
# 189   This unit is located at 621 Begonia Avenue, Co...
# ...                                                 ...
# 9828  This unit is located at 703 N 13th St. #308, S...
# 9837  This unit is located at 2215 Monument Ave., Ri...
# 9857  This unit is located at 22 Gray St, Arlington,...
# 9905  This unit is located at 14815 SE River Forest ...
# 9914  This unit is located at 423 N Carroll St, Madi...
#
#                                               amenities  bathrooms  bedrooms  \
# 40    Cable or Satellite,Dishwasher,Internet Access,...        1.0       1.0
# 45                                                  NaN        1.0       0.0
# 48                                                  NaN        1.0       1.0
# 185                                     Parking,Storage        1.0       1.0
# 189                                                 NaN        1.0       0.0
# ...                                                 ...        ...       ...
# 9828                                                NaN        2.0       2.0
# 9837                                                NaN        2.0       2.0
# 9857                                                NaN        3.5       4.0
# 9905                                                NaN        2.0       5.0
# 9914                     Fireplace,Parking,Refrigerator        2.0       7.0
#
#      currency fee  has_photo pets_allowed  price price_display price_type  \
# 40        USD  No  Thumbnail         Cats    942           942    Monthly
# 45        USD  No  Thumbnail         Cats   1095          1095    Monthly
# 48        USD  No  Thumbnail         Cats    775           775    Monthly
# 185       USD  No  Thumbnail         Cats    710           710    Monthly
# 189       USD  No  Thumbnail         Cats   1900          1900    Monthly
# ...       ...  ..        ...          ...    ...           ...        ...
# 9828      USD  No  Thumbnail         Cats   1995          1995    Monthly
# 9837      USD  No  Thumbnail         Cats   2800          2800    Monthly
# 9857      USD  No  Thumbnail         Cats   4500          4500    Monthly
# 9905      USD  No  Thumbnail         Cats   3895          3895    Monthly
# 9914      USD  No  Thumbnail         Cats   5355          5355    Monthly
#
#       square_feet                      address        cityname state  \
# 40            225      420 W Fullerton Parkway         Chicago    IL
# 45            231          1008 North 109th St         Seattle    WA
# 48            240               202 E Holly St      Bellingham    WA
# 185           265       404 Chamberlain Avenue         Madison    WI
# 189           275              621 Begonia Ave  Corona Del Mar    CA
# ...           ...                          ...             ...   ...
# 9828         2539           703 N 13th St #308     Saint Louis    MO
# 9837         2600         2215 Monument Avenue        Richmond    VA
# 9857         2700                   22 Gray St       Arlington    MA
# 9905         3000  14815 SE River Forest Drive       Milwaukie    OR
# 9914         3058             423 N Carroll St         Madison    WI
#
#       latitude  longitude     source        time
# 40     41.8625   -87.6825  RentLingo  1577359301
# 45     47.6160  -122.3275  RentLingo  1577360334
# 48     48.7871  -122.4437  RentLingo  1577360135
# 185    43.0724   -89.4003  RentLingo  1577358725
# 189    33.6019  -117.8637  RentLingo  1577016114
# ...        ...        ...        ...         ...
# 9828   38.6274   -90.3040  RentLingo  1577016704
# 9837   37.5300   -77.4770  RentLingo  1577016049
# 9857   42.4180   -71.1669  RentLingo  1577359455
# 9905   45.4248  -122.6129  RentLingo  1576667875
# 9914   43.0724   -89.4003  RentLingo  1577015655
#
# [485 rows x 22 columns]

# %% [markdown]
# ### I want to get only aparments in Austin and who allow only Dogs

# %%
condition1 = df["cityname"]=="Austin"
condition2 = df["pets_allowed"]=="Dogs"

df.loc[condition1&condition2]
# Out:
#              id                category                                 title  \
# 431  5668633423  housing/rent/apartment  Studio apartment 2104 San Gabriel St
# 557  5664594452  housing/rent/apartment            One BR 2108 San Gabriel St
#
#                                                   body amenities  bathrooms  \
# 431  This unit is located at 2104 San Gabriel St, A...       NaN        1.0
# 557  This unit is located at 2108 San Gabriel St, A...     Alarm        1.0
#
#      bedrooms currency fee  has_photo pets_allowed  price price_display  \
# 431       0.0      USD  No  Thumbnail         Dogs    925           925
# 557       1.0      USD  No  Thumbnail         Dogs    925           925
#
#     price_type  square_feet              address cityname state  latitude  \
# 431    Monthly          400  2104 San Gabriel St   Austin    TX   30.3054
# 557    Monthly          425  2108 San Gabriel St   Austin    TX   30.3054
#
#      longitude     source        time
# 431   -97.7497  RentLingo  1577359911
# 557   -97.7497  RentLingo  1577016823

# %%
df.loc[(df["cityname"]=="Los Angeles")&(df["pets_allowed"]=="Cats")]
# Out:
#               id                category  \
# 3171  5668627803  housing/rent/apartment
# 3297  5508828320  housing/rent/apartment
# 3302  5664597241  housing/rent/apartment
# 3799  5508832745  housing/rent/apartment
# 4119  5508742208  housing/rent/apartment
# 4122  5508817208  housing/rent/apartment
# 4125  5648134653  housing/rent/apartment
# 5340  5668638506  housing/rent/apartment
# 5433  5668638079  housing/rent/apartment
# 5874  5659916336  housing/rent/apartment
# 6671  5668638752  housing/rent/apartment
# 7143  5668637606  housing/rent/apartment
# 8979  5668631892  housing/rent/apartment
#
#                                                   title  \
# 3171                            One BR 1724 Butler Ave.
# 3297        Bright Los Angeles, One BR, One BA for rent
# 3302                           One BR 3646 Mentone Ave.
# 3799  One BR Apartment - Choose from a spacious studio.
# 4119      Apartment in move in condition in Los Angeles
# 4122         Welcome home to Sepulveda West Apartments!
# 4125                       One BR 9005, 9015 Burton Way
# 5340                               Two BR 3810 Wade St.
# 5433                     Two BR 3724-36 Inglewood Blvd.
# 5874                             Two BR 1339 Barry Ave.
# 6671                           Two BR 7007 Glasgow Ave.
# 7143                          Two BR 5452 Alvern Circle
# 8979                          Two BR 1230 Wellesley Ave
#
#                                                    body  \
# 3171  This unit is located at 1724 Butler Ave., Los ...
# 3297  Square footage: 700 square feet, unit number: ...
# 3302  This unit is located at 3646 Mentone Ave., Los...
# 3799  One or two beds floorplan Manor Apartments. Un...
# 4119  Square footage: 750 sq-ft, unit number: 117. S...
# 4122  Experience a sense of beautiful apartment comm...
# 4125  This unit is located at 9005, 9015 Burton Way,...
# 5340  This unit is located at 3810 Wade St., Los Ang...
# 5433  This unit is located at 3724-36 Inglewood Blvd...
# 5874  This unit is located at 1339 Barry Ave., Los A...
# 6671  This unit is located at 7007 Glasgow Ave., Los...
# 7143  This unit is located at 5452 Alvern Circle, Lo...
# 8979  This unit is located at 1230 Wellesley Ave, Lo...
#
#                                               amenities  bathrooms  bedrooms  \
# 3171                                                NaN        1.0       1.0
# 3297  AC,Cable or Satellite,Clubhouse,Dishwasher,Ele...        1.0       1.0
# 3302                                                NaN        1.0       1.0
# 3799  AC,Cable or Satellite,Dishwasher,Elevator,Fire...        1.0       1.0
# 4119                      AC,Fireplace,Gym,Parking,Pool        1.0       1.0
# 4122                 AC,Clubhouse,Gym,Pool,Refrigerator        1.0       1.0
# 4125                                                NaN        1.0       1.0
# 5340                                                NaN        2.0       2.0
# 5433                                                NaN        1.0       2.0
# 5874                                                NaN        2.0       2.0
# 6671                                                NaN        2.0       2.0
# 7143                                                NaN        2.0       2.0
# 8979                                                NaN        2.5       2.0
#
#      currency fee  has_photo pets_allowed  price price_display price_type  \
# 3171      USD  No  Thumbnail         Cats   2095          2095    Monthly
# 3297      USD  No  Thumbnail         Cats   2325          2325    Monthly
# 3302      USD  No  Thumbnail         Cats   2095          2095    Monthly
# 3799      USD  No  Thumbnail         Cats   2135          2135    Monthly
# 4119      USD  No  Thumbnail         Cats   3800          3800    Monthly
# 4122      USD  No  Thumbnail         Cats   2595          2595    Monthly
# 4125      USD  No  Thumbnail         Cats   2350          2350    Monthly
# 5340      USD  No  Thumbnail         Cats   2695          2695    Monthly
# 5433      USD  No  Thumbnail         Cats   2795          2795    Monthly
# 5874      USD  No  Thumbnail         Cats   2995          2995    Monthly
# 6671      USD  No  Thumbnail         Cats   2750          2750    Monthly
# 7143      USD  No  Thumbnail         Cats   2795          2795    Monthly
# 8979      USD  No  Thumbnail         Cats   4395          4395    Monthly
#
#       square_feet                      address     cityname state  latitude  \
# 3171          690           1724 Butler Avenue  Los Angeles    CA   34.0372
# 3297          700                          NaN  Los Angeles    CA   33.9550
# 3302          700          3646 Mentone Avenue  Los Angeles    CA   34.0372
# 3799          725                          NaN  Los Angeles    CA   34.1056
# 4119          750                          NaN  Los Angeles    CA   34.0630
# 4122          750                          NaN  Los Angeles    CA   33.9550
# 4125          750         9005 9015 Burton Way  Los Angeles    CA   34.0372
# 5340          840                 3810 Wade St  Los Angeles    CA   34.0372
# 5433          850  3724-36 Inglewood Boulevard  Los Angeles    CA   34.0372
# 5874          895            1339 Barry Avenue  Los Angeles    CA   34.0372
# 6671          980          7007 Glasgow Avenue  Los Angeles    CA   34.0372
# 7143         1050              5452 Alvern Cir  Los Angeles    CA   34.0372
# 8979         1500        1230 Wellesley Avenue  Los Angeles    CA   34.0372
#
#       longitude        source        time
# 3171  -118.2972     RentLingo  1577359492
# 3297  -118.3967  RentDigs.com  1568755678
# 3302  -118.2972     RentLingo  1577017069
# 3799  -118.3668  RentDigs.com  1568755968
# 4119  -118.4363  RentDigs.com  1568749134
# 4122  -118.3967  RentDigs.com  1568754936
# 4125  -118.2972     RentLingo  1575978067
# 5340  -118.2972     RentLingo  1577360242
# 5433  -118.2972     RentLingo  1577360200
# 5874  -118.2972     RentLingo  1576667598
# 6671  -118.2972     RentLingo  1577360259
# 7143  -118.2972     RentLingo  1577360169
# 8979  -118.2972     RentLingo  1577359787

# %% [markdown]
# ### How much is the most expensive apartment?

# %%
df["price"].max()
# Out:
# np.int64(52500)

# %% [markdown]
# ### I want to get the row of the most expensive aparment

# %%
df.loc[df["price"]==52500]
# Out:
#               id                category                      title  \
# 8829  5666447277  housing/rent/apartment  Studio apartment for rent
#
#                                                    body  \
# 8829  Barstow It's 14/18ft. studio apartment furnish...
#
#                                               amenities  bathrooms  bedrooms  \
# 8829  AC,Cable or Satellite,Internet Access,Patio/De...        1.0       0.0
#
#      currency fee  has_photo pets_allowed  price price_display price_type  \
# 8829      USD  No  Thumbnail          NaN  52500         52500    Monthly
#
#       square_feet            address cityname state  latitude  longitude  \
# 8829         1418  1101 Pueblo Drive  Barstow    CA    34.887   -117.035
#
#             source        time
# 8829  RentDigs.com  1577185712

# %%
#alternative
df.loc[df["price"]==df["price"].max()]
# Out:
#               id                category                      title  \
# 8829  5666447277  housing/rent/apartment  Studio apartment for rent
#
#                                                    body  \
# 8829  Barstow It's 14/18ft. studio apartment furnish...
#
#                                               amenities  bathrooms  bedrooms  \
# 8829  AC,Cable or Satellite,Internet Access,Patio/De...        1.0       0.0
#
#      currency fee  has_photo pets_allowed  price price_display price_type  \
# 8829      USD  No  Thumbnail          NaN  52500         52500    Monthly
#
#       square_feet            address cityname state  latitude  longitude  \
# 8829         1418  1101 Pueblo Drive  Barstow    CA    34.887   -117.035
#
#             source        time
# 8829  RentDigs.com  1577185712

# %% [markdown]
# ### I want only those apartments that costs less or equal to 1000

# %%
df.loc[df["price"]<=1000]
# Out:
#               id                category  \
# 0     5668626895  housing/rent/apartment
# 1     5664597177  housing/rent/apartment
# 3     5659918074  housing/rent/apartment
# 4     5668626759  housing/rent/apartment
# 7     5668626687  housing/rent/apartment
# ...          ...                     ...
# 9547  5664595590  housing/rent/apartment
# 9557  5650235161  housing/rent/apartment
# 9710  5668616581  housing/rent/apartment
# 9713  5509096590  housing/rent/apartment
# 9808  5668623359  housing/rent/apartment
#
#                                                   title  \
# 0     Studio apartment 2nd St NE, Uhland Terrace NE,...
# 1                     Studio apartment 814 Schutte Road
# 3                        Studio apartment 1717 12th Ave
# 4     Studio apartment Washington Blvd, N Cleveland ...
# 7     Studio apartment Oak St NW, 16th St NW, Washin...
# ...                                                 ...
# 9547                          Four BR 21 Idylwood Drive
# 9557                                  217 Binford SW Dr
# 9710                             Four BR 11 Maverick Dr
# 9713  Two BR - Come home to this roomy 2nd floor apa...
# 9808                           Two BR East Skelly Drive
#
#                                                    body  \
# 0     This unit is located at second St NE, Uhland T...
# 1     This unit is located at 814 Schutte Road, Evan...
# 3     This unit is located at 1717 12th Ave, Seattle...
# 4     This unit is located at Washington Blvd, N Cle...
# 7     This unit is located at Oak St NW, 16th St NW,...
# ...                                                 ...
# 9547  This unit is located at 21 Idylwood Drive, Cul...
# 9557  Come visit Spring Branch apartments today and ...
# 9710  This unit is located at eleven Maverick Dr, Pe...
# 9713  Dedicated dining area room, Galley Kitchen equ...
# 9808  This unit is located at East Skelly Drive, Tul...
#
#                                               amenities  bathrooms  bedrooms  \
# 0                                                   NaN        NaN       0.0
# 1                                                   NaN        NaN       1.0
# 3                                                   NaN        1.0       0.0
# 4                                                   NaN        NaN       0.0
# 7                                                   NaN        NaN       0.0
# ...                                                 ...        ...       ...
# 9547                                                NaN        4.0       4.0
# 9557                            Dishwasher,Refrigerator        2.0       4.0
# 9710  Dishwasher,Garbage Disposal,Parking,Patio/Deck...        3.0       4.0
# 9713                  Refrigerator,Storage,Washer Dryer        1.0       2.0
# 9808                                                NaN        2.0       2.0
#
#      currency fee  has_photo pets_allowed  price price_display price_type  \
# 0         USD  No  Thumbnail          NaN    790           790    Monthly
# 1         USD  No  Thumbnail          NaN    425           425    Monthly
# 3         USD  No  Thumbnail          NaN    925           925    Monthly
# 4         USD  No  Thumbnail          NaN    880           880    Monthly
# 7         USD  No  Thumbnail          NaN    840           840    Monthly
# ...       ...  ..        ...          ...    ...           ...        ...
# 9547      USD  No  Thumbnail    Cats,Dogs    575           575    Monthly
# 9557      USD  No  Thumbnail          NaN    665           665    Monthly
# 9710      USD  No  Thumbnail    Cats,Dogs    430           430    Monthly
# 9713      USD  No        Yes          NaN    595           595    Monthly
# 9808      USD  No  Thumbnail    Cats,Dogs    850           850    Monthly
#
#       square_feet               address    cityname state  latitude  \
# 0             101                   NaN  Washington    DC   38.9057
# 1             106        814 Schutte Rd  Evansville    IN   37.9680
# 3             116      1717 12th Avenue     Seattle    WA   47.6160
# 4             125                   NaN   Arlington    VA   38.8738
# 7             136                   NaN  Washington    DC   38.9328
# ...           ...                   ...         ...   ...       ...
# 9547         1950        21 Idylwood Dr   Cullowhee    NC   35.2850
# 9557         1968  217 Binford SW Drive  Huntsville    AL   34.7191
# 9710         2214     11 Maverick Drive   Pendleton    SC   34.6464
# 9713         2216                   NaN      Dayton    OH   39.7942
# 9808         2492                   NaN       Tulsa    OK   36.1160
#
#       longitude        source        time
# 0      -76.9861     RentLingo  1577359415
# 1      -87.6621     RentLingo  1577017063
# 3     -122.3275     RentLingo  1576667743
# 4      -77.1055     RentLingo  1577359401
# 7      -77.0297     RentLingo  1577359393
# ...         ...           ...         ...
# 9547   -83.1791     RentLingo  1577016906
# 9557   -86.5855     ListedBuy  1576100663
# 9710   -82.7686     RentLingo  1577358737
# 9713   -84.2701  RentDigs.com  1568773159
# 9808   -95.9281     RentLingo  1577359173
#
# [3068 rows x 22 columns]

# %% [markdown]
# ### I want to get only those aparments in Texax (TX) and save into another variable

# %%
texas_df = df.loc[df["state"]=="TX"]

# %%
#check the structure of texas_df
texas_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1737 entries, 17 to 9982
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             1737 non-null   int64
#  1   category       1737 non-null   object
#  2   title          1737 non-null   object
#  3   body           1737 non-null   object
#  4   amenities      1217 non-null   object
#  5   bathrooms      1730 non-null   float64
#  6   bedrooms       1737 non-null   float64
#  7   currency       1737 non-null   object
#  8   fee            1737 non-null   object
#  9   has_photo      1737 non-null   object
#  10  pets_allowed   890 non-null    object
#  11  price          1737 non-null   int64
#  12  price_display  1737 non-null   object
#  13  price_type     1737 non-null   object
#  14  square_feet    1737 non-null   int64
#  15  address        1360 non-null   object
#  16  cityname       1737 non-null   object
#  17  state          1737 non-null   object
#  18  latitude       1737 non-null   float64
#  19  longitude      1737 non-null   float64
#  20  source         1737 non-null   object
#  21  time           1737 non-null   int64
# dtypes: float64(4), int64(4), object(14)
# memory usage: 312.1+ KB

# %% [markdown]
# ### The indexes of the rows are weird, I want to reset them

# %%
texas_df = texas_df.reset_index(drop=True)
texas_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1737 entries, 0 to 1736
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             1737 non-null   int64
#  1   category       1737 non-null   object
#  2   title          1737 non-null   object
#  3   body           1737 non-null   object
#  4   amenities      1217 non-null   object
#  5   bathrooms      1730 non-null   float64
#  6   bedrooms       1737 non-null   float64
#  7   currency       1737 non-null   object
#  8   fee            1737 non-null   object
#  9   has_photo      1737 non-null   object
#  10  pets_allowed   890 non-null    object
#  11  price          1737 non-null   int64
#  12  price_display  1737 non-null   object
#  13  price_type     1737 non-null   object
#  14  square_feet    1737 non-null   int64
#  15  address        1360 non-null   object
#  16  cityname       1737 non-null   object
#  17  state          1737 non-null   object
#  18  latitude       1737 non-null   float64
#  19  longitude      1737 non-null   float64
#  20  source         1737 non-null   object
#  21  time           1737 non-null   int64
# dtypes: float64(4), int64(4), object(14)
# memory usage: 298.7+ KB

# %% [markdown]
# ### What is the price of the cheapest apartment in Texas?

# %%
price = texas_df["price"].min()
print(price)
# Out:
# 300

# %% [markdown]
# # Homework
#
# Continuing with this dataset, answer the following questions by providing the respecting code

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             10000 non-null  int64
#  1   category       10000 non-null  object
#  2   title          10000 non-null  object
#  3   body           10000 non-null  object
#  4   amenities      6451 non-null   object
#  5   bathrooms      9966 non-null   float64
#  6   bedrooms       9993 non-null   float64
#  7   currency       10000 non-null  object
#  8   fee            10000 non-null  object
#  9   has_photo      10000 non-null  object
#  10  pets_allowed   5837 non-null   object
#  11  price          10000 non-null  int64
#  12  price_display  10000 non-null  object
#  13  price_type     10000 non-null  object
#  14  square_feet    10000 non-null  int64
#  15  address        6673 non-null   object
#  16  cityname       9923 non-null   object
#  17  state          9923 non-null   object
#  18  latitude       9990 non-null   float64
#  19  longitude      9990 non-null   float64
#  20  source         10000 non-null  object
#  21  time           10000 non-null  int64
# dtypes: float64(4), int64(4), object(14)
# memory usage: 1.7+ MB

# %% [markdown]
# ### How many categories of apartment exist in the dataset?

# %% [markdown]
# ### What does the dataset mean with amenities? How many different amenities and how frequent they appear in the whole dataset?

# %% [markdown]
# ### Rename the column "state" to "state_code"

# %% [markdown]
# ### Create a new column called "statename" where you put the names of the states based on the column "state_code"
#
# Hint: You can ask chatgpt to create a dictionary with the state codes and states names

# %% [markdown]
# ### Create a cross table or contingeny table with the counts of two variables "bathrooms" and "bedrooms" in order to see counts of all different combination between bathrooms and bedrooms
#
# Hint: use pd.crosstab function

# %% [markdown]
# ### Is there only US dollars as currency? If not, which other ones?

# %% [markdown]
# ### Create two different dataframes: west_df and east_df
#
# west_df is a dataframe contain only those apartments in the west coast of the US.
#
# east_df is a dataframe contain only those apartments in the east coast of the US.

# %% [markdown]
# ### Where is more expensive to live: in the west coast or east coast?
#
# Hint: Calculate the means or averages of apartment prices. Don't run statistical tests

# %% [markdown]
# ### How many aparments in Florida have a pool?

# %% [markdown]
# ### In which states of the west coast are the top 5 biggest apartments?
#
# hint: use df.sort() function

# %% [markdown]
# ### Is there a prominent source in the west coast and east coast?
#
# Hint: the column source contain the (internet) sites where the data was gathered.

# %% [markdown]
# ### Create a new dataframe with all the cities in the border with Mexico
#
# The new dataframe should be called mex_df

# %% [markdown]
# ### How many bedrooms and bathrooms are in average in the cities from mex_df

# %% [markdown]
# ### From the top 10 cheapest cities next to Mexico border, do all of them have AC as amenities?
